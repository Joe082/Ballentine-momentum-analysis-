# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("/Users/apple/Desktop/y4s2/capstone/week 2 data set/R1G_R1V.xlsx")

# %% [markdown]
# slow and fast signal

# %%
monthly_ratio = df.resample('M', on='Date')['ratio'].mean()
monthly_ratio_pct_change = monthly_ratio.pct_change().dropna()


lookback_fast = 2
lookback_slow = 12

fast_signal = monthly_ratio_pct_change.rolling(window=lookback_fast).mean().dropna()
slow_signal = monthly_ratio_pct_change.rolling(window=lookback_slow).mean().dropna()

monthly_ratio.index = monthly_ratio.index.to_period('M')
fast_signal.index = fast_signal.index.to_period('M')
slow_signal.index = slow_signal.index.to_period('M')

# Now the indices of monthly_ratio, fast_signal, and slow_signal only contain year and month
monthly_ratio, fast_signal, slow_signal

monthly_ratio.to_frame()
# Out:
#             ratio
# Date
# 1991-01  0.994711
# 1991-02  1.014354
# 1991-03  1.031177
# 1991-04  1.048159
# 1991-05  1.042428
# ...           ...
# 2023-08  1.245527
# 2023-09  1.262099
# 2023-10  1.291403
# 2023-11  1.329225
# 2023-12  1.315847
#
# [396 rows x 1 columns]

# %%
common_length = min(len(fast_signal), len(slow_signal))
aligned_fast_signal = fast_signal[-common_length:]
aligned_slow_signal = slow_signal[-common_length:]

def classify_market_condition(slow, fast):
    if slow >= 0 and fast >= 0:
        return 'Bull'
    elif slow >= 0 and fast < 0:
        return 'Correction'
    elif slow < 0 and fast < 0:
        return 'Bear'
    elif slow < 0 and fast >= 0:
        return 'Rebound'
    else:
        return 'Undefined'
    
    
market_conditions = pd.DataFrame({
    'Slow Signal': aligned_slow_signal,
    'Fast Signal': aligned_fast_signal
}).apply(lambda row: classify_market_condition(row['Slow Signal'], row['Fast Signal']), axis=1)

market_conditions.to_frame()
# Out:
#                   0
# Date
# 1992-01        Bull
# 1992-02  Correction
# 1992-03  Correction
# 1992-04  Correction
# 1992-05        Bear
# ...             ...
# 2023-08  Correction
# 2023-09        Bull
# 2023-10        Bull
# 2023-11        Bull
# 2023-12        Bull
#
# [384 rows x 1 columns]

# %%
merged_df = pd.merge(monthly_ratio, market_conditions, on='Date', how='inner')
merged_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/apple/Desktop/paper methods.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/apple/Desktop/paper%20methods.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> merged_df = pd.merge(monthly_ratio, market_conditions, on='Date', how='inner')
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/paper%20methods.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> merged_df.head(5)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:681, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     664 def __init__(
#     665     self,
#     666     left: DataFrame | Series,
#    (...)
#     678     validate: str | None = None,
#     679 ) -> None:
#     680     _left = _validate_operand(left)
# --> 681     _right = _validate_operand(right)
#     682     self.left = self.orig_left = _left
#     683     self.right = self.orig_right = _right
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:2572, in _validate_operand(obj)
#    2570 elif isinstance(obj, ABCSeries):
#    2571     if obj.name is None:
# -> 2572         raise ValueError("Cannot merge a Series without a name")
#    2573     return obj.to_frame()
#    2574 else:
#
# ValueError: Cannot merge a Series without a name

# %%
import matplotlib.patches as mpatches

merged_df.reset_index(inplace=True)
merged_df['Date'] = merged_df['Date'].dt.to_timestamp()

#plot the four market condition
color_map = {
    'Bull': 'green',
    'Bear': 'red',
    'Correction': 'pink',
    'Rebound': 'yellow'
}
plt.figure(figsize=(10, 6))
for index, row in merged_df.iterrows():
    plt.scatter(row['Date'], row['ratio'], color=color_map.get(row[0], 'blue'))

#plot the monthly ratio
plt.plot(merged_df['Date'], merged_df['ratio'], linestyle='-' , color='gray')

#add a legend for market condition
legend_handles = []
for condition, color in color_map.items():
    # Plot an empty list to create the legend entry
    legend_handles.append(mpatches.Patch(color=color, label=condition))


# Add the legend to the plot
plt.legend(handles=legend_handles, loc='upper left', bbox_to_anchor=(1, 1), title='Market Condition')
plt.title('Monthly Ratio Over Time with market conditions')
plt.xlabel('Date')
plt.ylabel('Ratio')
plt.xticks(rotation=45)  # Rotate date labels for better readability
plt.tight_layout()  # Adjust subplot params
plt.show()
